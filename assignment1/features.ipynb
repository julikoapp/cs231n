# %%
# This mounts your Google Drive to the Colab VM.
from google.colab import drive
drive.mount('/content/drive')

# TODO: Enter the foldername in your Drive where you have saved the unzipped
# assignment folder, e.g. 'cs231n/assignments/assignment1/'
FOLDERNAME = 'cs231n/assignments/assignment1/'
assert FOLDERNAME is not None, "[!] Enter the foldername."

# Now that we've mounted your Drive, this ensures that
# the Python interpreter of the Colab VM can load
# python files from within it.
import sys
sys.path.append('/content/drive/My Drive/{}'.format(FOLDERNAME))

# This downloads the CIFAR-10 dataset to your Drive
# if it doesn't already exist.
# %cd /content/drive/My\ Drive/$FOLDERNAME/cs231n/datasets/
# !bash get_datasets.sh
# %cd /content/drive/My\ Drive/$FOLDERNAME
# Out:
# Mounted at /content/drive
# /content/drive/My Drive/cs231n/assignments/assignment1/cs231n/datasets
# /content/drive/My Drive/cs231n/assignments/assignment1

# %% [markdown]
# # Image features exercise
# *Complete and hand in this completed worksheet (including its outputs and any supporting code outside of the worksheet) with your assignment submission. For more details see the [assignments page](http://vision.stanford.edu/teaching/cs231n/assignments.html) on the course website.*
#
# We have seen that we can achieve reasonable performance on an image classification task by training a linear classifier on the pixels of the input image. In this exercise we will show that we can improve our classification performance by training linear classifiers not on raw pixels but on features that are computed from the raw pixels.
#
# All of your work for this exercise will be done in this notebook.

# %%
import random
import numpy as np
from cs231n.data_utils import load_CIFAR10
import matplotlib.pyplot as plt


# %matplotlib inline
plt.rcParams['figure.figsize'] = (10.0, 8.0) # set default size of plots
plt.rcParams['image.interpolation'] = 'nearest'
plt.rcParams['image.cmap'] = 'gray'

# for auto-reloading extenrnal modules
# see http://stackoverflow.com/questions/1907993/autoreload-of-modules-in-ipython
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# ## Load data
# Similar to previous exercises, we will load CIFAR-10 data from disk.

# %%
from cs231n.features import color_histogram_hsv, hog_feature

def get_CIFAR10_data(num_training=49000, num_validation=1000, num_test=1000):
    # Load the raw CIFAR-10 data
    cifar10_dir = 'cs231n/datasets/cifar-10-batches-py'

    # Cleaning up variables to prevent loading data multiple times (which may cause memory issue)
    try:
       del X_train, y_train
       del X_test, y_test
       print('Clear previously loaded data.')
    except:
       pass

    X_train, y_train, X_test, y_test = load_CIFAR10(cifar10_dir)

    # Subsample the data
    mask = list(range(num_training, num_training + num_validation))
    X_val = X_train[mask]
    y_val = y_train[mask]
    mask = list(range(num_training))
    X_train = X_train[mask]
    y_train = y_train[mask]
    mask = list(range(num_test))
    X_test = X_test[mask]
    y_test = y_test[mask]

    return X_train, y_train, X_val, y_val, X_test, y_test

X_train, y_train, X_val, y_val, X_test, y_test = get_CIFAR10_data()

# %% [markdown]
# ## Extract Features
# For each image we will compute a Histogram of Oriented
# Gradients (HOG) as well as a color histogram using the hue channel in HSV
# color space. We form our final feature vector for each image by concatenating
# the HOG and color histogram feature vectors.
#
# Roughly speaking, HOG should capture the texture of the image while ignoring
# color information, and the color histogram represents the color of the input
# image while ignoring texture. As a result, we expect that using both together
# ought to work better than using either alone. Verifying this assumption would
# be a good thing to try for your own interest.
#
# The `hog_feature` and `color_histogram_hsv` functions both operate on a single
# image and return a feature vector for that image. The extract_features
# function takes a set of images and a list of feature functions and evaluates
# each feature function on each image, storing the results in a matrix where
# each column is the concatenation of all feature vectors for a single image.

# %%
from cs231n.features import *

num_color_bins = 10 # Number of bins in the color histogram
feature_fns = [hog_feature, lambda img: color_histogram_hsv(img, nbin=num_color_bins)]
X_train_feats = extract_features(X_train, feature_fns, verbose=True)
X_val_feats = extract_features(X_val, feature_fns)
X_test_feats = extract_features(X_test, feature_fns)

# Preprocessing: Subtract the mean feature
mean_feat = np.mean(X_train_feats, axis=0, keepdims=True)
X_train_feats -= mean_feat
X_val_feats -= mean_feat
X_test_feats -= mean_feat

# Preprocessing: Divide by standard deviation. This ensures that each feature
# has roughly the same scale.
std_feat = np.std(X_train_feats, axis=0, keepdims=True)
X_train_feats /= std_feat
X_val_feats /= std_feat
X_test_feats /= std_feat

# Preprocessing: Add a bias dimension
X_train_feats = np.hstack([X_train_feats, np.ones((X_train_feats.shape[0], 1))])
X_val_feats = np.hstack([X_val_feats, np.ones((X_val_feats.shape[0], 1))])
X_test_feats = np.hstack([X_test_feats, np.ones((X_test_feats.shape[0], 1))])
# Out:
# Done extracting features for 1000 / 49000 images
# Done extracting features for 2000 / 49000 images
# Done extracting features for 3000 / 49000 images
# Done extracting features for 4000 / 49000 images
# Done extracting features for 5000 / 49000 images
# Done extracting features for 6000 / 49000 images
# Done extracting features for 7000 / 49000 images
# Done extracting features for 8000 / 49000 images
# Done extracting features for 9000 / 49000 images
# Done extracting features for 10000 / 49000 images
# Done extracting features for 11000 / 49000 images
# Done extracting features for 12000 / 49000 images
# Done extracting features for 13000 / 49000 images
# Done extracting features for 14000 / 49000 images
# Done extracting features for 15000 / 49000 images
# Done extracting features for 16000 / 49000 images
# Done extracting features for 17000 / 49000 images
# Done extracting features for 18000 / 49000 images
# Done extracting features for 19000 / 49000 images
# Done extracting features for 20000 / 49000 images
# Done extracting features for 21000 / 49000 images
# Done extracting features for 22000 / 49000 images
# Done extracting features for 23000 / 49000 images
# Done extracting features for 24000 / 49000 images
# Done extracting features for 25000 / 49000 images
# Done extracting features for 26000 / 49000 images
# Done extracting features for 27000 / 49000 images
# Done extracting features for 28000 / 49000 images
# Done extracting features for 29000 / 49000 images
# Done extracting features for 30000 / 49000 images
# Done extracting features for 31000 / 49000 images
# Done extracting features for 32000 / 49000 images
# Done extracting features for 33000 / 49000 images
# Done extracting features for 34000 / 49000 images
# Done extracting features for 35000 / 49000 images
# Done extracting features for 36000 / 49000 images
# Done extracting features for 37000 / 49000 images
# Done extracting features for 38000 / 49000 images
# Done extracting features for 39000 / 49000 images
# Done extracting features for 40000 / 49000 images
# Done extracting features for 41000 / 49000 images
# Done extracting features for 42000 / 49000 images
# Done extracting features for 43000 / 49000 images
# Done extracting features for 44000 / 49000 images
# Done extracting features for 45000 / 49000 images
# Done extracting features for 46000 / 49000 images
# Done extracting features for 47000 / 49000 images
# Done extracting features for 48000 / 49000 images
# Done extracting features for 49000 / 49000 images

# %% [markdown]
# ## Train SVM on features
# Using the multiclass SVM code developed earlier in the assignment, train SVMs on top of the features extracted above; this should achieve better results than training SVMs directly on top of raw pixels.

# %%
# Use the validation set to tune the learning rate and regularization strength

from cs231n.classifiers.linear_classifier import LinearSVM

learning_rates = [1e-9, 1e-8, 1e-7]
regularization_strengths = [5e4, 5e5, 5e6]

results = {}
best_val = -1
best_svm = None

################################################################################
# TODO:                                                                        #
# Use the validation set to set the learning rate and regularization strength. #
# This should be identical to the validation that you did for the SVM; save    #
# the best trained classifer in best_svm. You might also want to play          #
# with different numbers of bins in the color histogram. If you are careful    #
# you should be able to get accuracy of near 0.44 on the validation set.       #
################################################################################
# *****START OF YOUR CODE (DO NOT DELETE/MODIFY THIS LINE)*****

for lr in learning_rates:
  for rg in regularization_strengths:
    svm = LinearSVM()
    loss_hist = svm.train(X_train_feats, y_train, learning_rate = lr, reg=rg)
    y_train_pred = svm.predict(X_train_feats)
    train_acc = np.mean(y_train_pred == y_train)
    y_pred = svm.predict(X_val_feats)
    val_acc = np.sum(y_val == y_pred) / len(y_val)

    results[(lr, rg)] = (train_acc, val_acc)
    if val_acc > best_val:
      best_val = val_acc
      best_svm = svm

# *****END OF YOUR CODE (DO NOT DELETE/MODIFY THIS LINE)*****

# Print out results.
for lr, reg in sorted(results):
    train_accuracy, val_accuracy = results[(lr, reg)]
    print('lr %e reg %e train accuracy: %f val accuracy: %f' % (
                lr, reg, train_accuracy, val_accuracy))

print('best validation accuracy achieved: %f' % best_val)
# Out:
# lr 1.000000e-09 reg 5.000000e+04 train accuracy: 0.405367 val accuracy: 0.405000
# lr 1.000000e-09 reg 5.000000e+05 train accuracy: 0.441367 val accuracy: 0.440000
# lr 1.000000e-09 reg 5.000000e+06 train accuracy: 0.491551 val accuracy: 0.478000
# lr 1.000000e-08 reg 5.000000e+04 train accuracy: 0.434796 val accuracy: 0.438000
# lr 1.000000e-08 reg 5.000000e+05 train accuracy: 0.490102 val accuracy: 0.473000
# lr 1.000000e-08 reg 5.000000e+06 train accuracy: 0.474245 val accuracy: 0.472000
# lr 1.000000e-07 reg 5.000000e+04 train accuracy: 0.486286 val accuracy: 0.477000
# lr 1.000000e-07 reg 5.000000e+05 train accuracy: 0.481347 val accuracy: 0.461000
# lr 1.000000e-07 reg 5.000000e+06 train accuracy: 0.422571 val accuracy: 0.436000
# best validation accuracy achieved: 0.478000

# %%
# Evaluate your trained SVM on the test set: you should be able to get at least 0.40
y_test_pred = best_svm.predict(X_test_feats)
test_accuracy = np.mean(y_test == y_test_pred)
print(test_accuracy)
# Out:
# 0.477

# %%
# An important way to gain intuition about how an algorithm works is to
# visualize the mistakes that it makes. In this visualization, we show examples
# of images that are misclassified by our current system. The first column
# shows images that our system labeled as "plane" but whose true label is
# something other than "plane".

examples_per_class = 8
classes = ['plane', 'car', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck']
for cls, cls_name in enumerate(classes):
    idxs = np.where((y_test != cls) & (y_test_pred == cls))[0]
    idxs = np.random.choice(idxs, examples_per_class, replace=False)
    for i, idx in enumerate(idxs):
        plt.subplot(examples_per_class, len(classes), i * len(classes) + cls + 1)
        plt.imshow(X_test[idx].astype('uint8'))
        plt.axis('off')
        if i == 0:
            plt.title(cls_name)
plt.show()

# %% [markdown]
# ### Inline question 1:
# Describe the misclassification results that you see. Do they make sense?
#
#
# $\color{blue}{\textit Your Answer:}$

# %% [markdown]
# most of them - yes. like image of the horse is classified incorreclty as bird, but if we look at it then it is understood then horse's view from the side is like the bird with beak

# %% [markdown]
# ## Neural Network on image features
# Earlier in this assigment we saw that training a two-layer neural network on raw pixels achieved better classification performance than linear classifiers on raw pixels. In this notebook we have seen that linear classifiers on image features outperform linear classifiers on raw pixels.
#
# For completeness, we should also try training a neural network on image features. This approach should outperform all previous approaches: you should easily be able to achieve over 55% classification accuracy on the test set; our best model achieves about 60% classification accuracy.

# %%
# Preprocessing: Remove the bias dimension
# Make sure to run this cell only ONCE
print(X_train_feats.shape)
X_train_feats = X_train_feats[:, :-1]
X_val_feats = X_val_feats[:, :-1]
X_test_feats = X_test_feats[:, :-1]

print(X_train_feats.shape)
# Out:
# (49000, 155)
# (49000, 154)

# %%
from cs231n.classifiers.fc_net import TwoLayerNet
from cs231n.solver import Solver

input_dim = X_train_feats.shape[1]
hidden_dim = 500
num_classes = 10

data = {
    'X_train': X_train_feats,
    'y_train': y_train,
    'X_val': X_val_feats,
    'y_val': y_val,
    'X_test': X_test_feats,
    'y_test': y_test,
}

# net = TwoLayerNet(input_dim, hidden_dim, num_classes)
best_net = None
best_val = -1

################################################################################
# TODO: Train a two-layer neural network on image features. You may want to    #
# cross-validate various parameters as in previous sections. Store your best   #
# model in the best_net variable.                                              #
################################################################################
# *****START OF YOUR CODE (DO NOT DELETE/MODIFY THIS LINE)*****


# solver = Solver(net, data, update_rule='sgd', optim_config={'learning_rate': 1e-5})
# solver.train()

best_net = net

# learning_rates = np.arange(1e-5, 1e-3, 1e-1)

learning_rates = [1.0]
regularization_strengths = [1e-3, 3e-3]
# regularization_strengths = np.arange(0, 2.5e4, 1e4)

for lr in learning_rates:
  for rg in regularization_strengths:
    print("lr, rg: ", lr, rg)
    model = TwoLayerNet(input_dim, hidden_dim, num_classes, reg=rg)
    solver = Solver(model, data, update_rule='sgd', optim_config={'learning_rate': lr})
    solver.train()
    print('train accuracy: %.4f' %solver.train_acc_history[-1])
    print('validation accuracy: %.4f' %solver.val_acc_history[-1])
    if solver.best_val_acc > best_val:
      best_net = model
      llearning = lr
      best_val = solver.best_val_acc
# *****END OF YOUR CODE (DO NOT DELETE/MODIFY THIS LINE)*****
# Out:
# lr, rg:  1.0 0.001
# (Iteration 1 / 4900) loss: 2.302585
# (Epoch 0 / 10) train acc: 0.102000; val_acc: 0.105000
# (Iteration 11 / 4900) loss: 2.301738
# (Iteration 21 / 4900) loss: 2.303983
# (Iteration 31 / 4900) loss: 2.294210
# (Iteration 41 / 4900) loss: 2.170338
# (Iteration 51 / 4900) loss: 1.926979
# (Iteration 61 / 4900) loss: 1.948550
# (Iteration 71 / 4900) loss: 1.832246
# (Iteration 81 / 4900) loss: 1.645198
# (Iteration 91 / 4900) loss: 1.702273
# (Iteration 101 / 4900) loss: 1.632445
# (Iteration 111 / 4900) loss: 1.666488
# (Iteration 121 / 4900) loss: 1.522080
# (Iteration 131 / 4900) loss: 1.605920
# (Iteration 141 / 4900) loss: 1.599124
# (Iteration 151 / 4900) loss: 1.670380
# (Iteration 161 / 4900) loss: 1.691508
# (Iteration 171 / 4900) loss: 1.471977
# (Iteration 181 / 4900) loss: 1.668369
# (Iteration 191 / 4900) loss: 1.641589
# (Iteration 201 / 4900) loss: 1.441150
# (Iteration 211 / 4900) loss: 1.522661
# (Iteration 221 / 4900) loss: 1.524021
# (Iteration 231 / 4900) loss: 1.635375
# (Iteration 241 / 4900) loss: 1.635540
# (Iteration 251 / 4900) loss: 1.688336
# (Iteration 261 / 4900) loss: 1.546897
# (Iteration 271 / 4900) loss: 1.392363
# (Iteration 281 / 4900) loss: 1.524570
# (Iteration 291 / 4900) loss: 1.490000
# (Iteration 301 / 4900) loss: 1.533974
# (Iteration 311 / 4900) loss: 1.514089
# (Iteration 321 / 4900) loss: 1.638087
# (Iteration 331 / 4900) loss: 1.588621
# (Iteration 341 / 4900) loss: 1.447113
# (Iteration 351 / 4900) loss: 1.402002
# (Iteration 361 / 4900) loss: 1.757652
# (Iteration 371 / 4900) loss: 1.417008
# (Iteration 381 / 4900) loss: 1.567239
# (Iteration 391 / 4900) loss: 1.361888
# (Iteration 401 / 4900) loss: 1.529853
# (Iteration 411 / 4900) loss: 1.407390
# (Iteration 421 / 4900) loss: 1.541799
# (Iteration 431 / 4900) loss: 1.554318
# (Iteration 441 / 4900) loss: 1.642621
# (Iteration 451 / 4900) loss: 1.310903
# (Iteration 461 / 4900) loss: 1.454168
# (Iteration 471 / 4900) loss: 1.687501
# (Iteration 481 / 4900) loss: 1.509436
# (Epoch 1 / 10) train acc: 0.531000; val_acc: 0.501000
# (Iteration 491 / 4900) loss: 1.481395
# (Iteration 501 / 4900) loss: 1.324521
# (Iteration 511 / 4900) loss: 1.580675
# (Iteration 521 / 4900) loss: 1.504765
# (Iteration 531 / 4900) loss: 1.661178
# (Iteration 541 / 4900) loss: 1.431869
# (Iteration 551 / 4900) loss: 1.394181
# (Iteration 561 / 4900) loss: 1.346130
# (Iteration 571 / 4900) loss: 1.524175
# (Iteration 581 / 4900) loss: 1.339858
# (Iteration 591 / 4900) loss: 1.308820
# (Iteration 601 / 4900) loss: 1.509764
# (Iteration 611 / 4900) loss: 1.488354
# (Iteration 621 / 4900) loss: 1.333504
# (Iteration 631 / 4900) loss: 1.434164
# (Iteration 641 / 4900) loss: 1.492186
# (Iteration 651 / 4900) loss: 1.420577
# (Iteration 661 / 4900) loss: 1.545169
# (Iteration 671 / 4900) loss: 1.279388
# (Iteration 681 / 4900) loss: 1.828986
# (Iteration 691 / 4900) loss: 1.316095
# (Iteration 701 / 4900) loss: 1.342674
# (Iteration 711 / 4900) loss: 1.592216
# (Iteration 721 / 4900) loss: 1.524432
# (Iteration 731 / 4900) loss: 1.334799
# (Iteration 741 / 4900) loss: 1.556524
# (Iteration 751 / 4900) loss: 1.418472
# (Iteration 761 / 4900) loss: 1.514848
# (Iteration 771 / 4900) loss: 1.394587
# (Iteration 781 / 4900) loss: 1.295501
# (Iteration 791 / 4900) loss: 1.405972
# (Iteration 801 / 4900) loss: 1.482958
# (Iteration 811 / 4900) loss: 1.474556
# (Iteration 821 / 4900) loss: 1.168007
# (Iteration 831 / 4900) loss: 1.516979
# (Iteration 841 / 4900) loss: 1.466734
# (Iteration 851 / 4900) loss: 1.379443
# (Iteration 861 / 4900) loss: 1.406441
# (Iteration 871 / 4900) loss: 1.458199
# (Iteration 881 / 4900) loss: 1.445851
# (Iteration 891 / 4900) loss: 1.451074
# (Iteration 901 / 4900) loss: 1.389266
# (Iteration 911 / 4900) loss: 1.275475
# (Iteration 921 / 4900) loss: 1.697082
# (Iteration 931 / 4900) loss: 1.487086
# (Iteration 941 / 4900) loss: 1.363887
# (Iteration 951 / 4900) loss: 1.451433
# (Iteration 961 / 4900) loss: 1.320197
# (Iteration 971 / 4900) loss: 1.277490
# (Epoch 2 / 10) train acc: 0.574000; val_acc: 0.510000
# (Iteration 981 / 4900) loss: 1.445982
# (Iteration 991 / 4900) loss: 1.476352
# (Iteration 1001 / 4900) loss: 1.234765
# (Iteration 1011 / 4900) loss: 1.166435
# (Iteration 1021 / 4900) loss: 1.559087
# (Iteration 1031 / 4900) loss: 1.365462
# (Iteration 1041 / 4900) loss: 1.228051
# (Iteration 1051 / 4900) loss: 1.227656
# (Iteration 1061 / 4900) loss: 1.145935
# (Iteration 1071 / 4900) loss: 1.166262
# (Iteration 1081 / 4900) loss: 1.465632
# (Iteration 1091 / 4900) loss: 1.586726
# (Iteration 1101 / 4900) loss: 1.336812
# (Iteration 1111 / 4900) loss: 1.444297
# (Iteration 1121 / 4900) loss: 1.395810
# (Iteration 1131 / 4900) loss: 1.680522
# (Iteration 1141 / 4900) loss: 1.274382
# (Iteration 1151 / 4900) loss: 1.406302
# (Iteration 1161 / 4900) loss: 1.366413
# (Iteration 1171 / 4900) loss: 1.421997
# (Iteration 1181 / 4900) loss: 1.525682
# (Iteration 1191 / 4900) loss: 1.258369
# (Iteration 1201 / 4900) loss: 1.397993
# (Iteration 1211 / 4900) loss: 1.603021
# (Iteration 1221 / 4900) loss: 1.397883
# (Iteration 1231 / 4900) loss: 1.317193
# (Iteration 1241 / 4900) loss: 1.343369
# (Iteration 1251 / 4900) loss: 1.384786
# (Iteration 1261 / 4900) loss: 1.576126
# (Iteration 1271 / 4900) loss: 1.269419
# (Iteration 1281 / 4900) loss: 1.462650
# (Iteration 1291 / 4900) loss: 1.394241
# (Iteration 1301 / 4900) loss: 1.470704
# (Iteration 1311 / 4900) loss: 1.345148
# (Iteration 1321 / 4900) loss: 1.211196
# (Iteration 1331 / 4900) loss: 1.250383
# (Iteration 1341 / 4900) loss: 1.467341
# (Iteration 1351 / 4900) loss: 1.254425
# (Iteration 1361 / 4900) loss: 1.480572
# (Iteration 1371 / 4900) loss: 1.108854
# (Iteration 1381 / 4900) loss: 1.354625
# (Iteration 1391 / 4900) loss: 1.194331
# (Iteration 1401 / 4900) loss: 1.215082
# (Iteration 1411 / 4900) loss: 1.391676
# (Iteration 1421 / 4900) loss: 1.504913
# (Iteration 1431 / 4900) loss: 1.443531
# (Iteration 1441 / 4900) loss: 1.718759
# (Iteration 1451 / 4900) loss: 1.249109
# (Iteration 1461 / 4900) loss: 1.326335
# (Epoch 3 / 10) train acc: 0.597000; val_acc: 0.520000
# (Iteration 1471 / 4900) loss: 1.428566
# (Iteration 1481 / 4900) loss: 1.427653
# (Iteration 1491 / 4900) loss: 1.410034
# (Iteration 1501 / 4900) loss: 1.485480
# (Iteration 1511 / 4900) loss: 1.406388
# (Iteration 1521 / 4900) loss: 1.316550
# (Iteration 1531 / 4900) loss: 1.409232
# (Iteration 1541 / 4900) loss: 1.667343
# (Iteration 1551 / 4900) loss: 1.414945
# (Iteration 1561 / 4900) loss: 1.509630
# (Iteration 1571 / 4900) loss: 1.395066
# (Iteration 1581 / 4900) loss: 1.201626
# (Iteration 1591 / 4900) loss: 1.610187
# (Iteration 1601 / 4900) loss: 1.297821
# (Iteration 1611 / 4900) loss: 1.460002
# (Iteration 1621 / 4900) loss: 1.477177
# (Iteration 1631 / 4900) loss: 1.373149
# (Iteration 1641 / 4900) loss: 1.336053
# (Iteration 1651 / 4900) loss: 1.580671
# (Iteration 1661 / 4900) loss: 1.564775
# (Iteration 1671 / 4900) loss: 1.478277
# (Iteration 1681 / 4900) loss: 1.472905
# (Iteration 1691 / 4900) loss: 1.549856
# (Iteration 1701 / 4900) loss: 1.182258
# (Iteration 1711 / 4900) loss: 1.532022
# (Iteration 1721 / 4900) loss: 1.512659
# (Iteration 1731 / 4900) loss: 1.235746
# (Iteration 1741 / 4900) loss: 1.119609
# (Iteration 1751 / 4900) loss: 1.293642
# (Iteration 1761 / 4900) loss: 1.289263
# (Iteration 1771 / 4900) loss: 1.363653
# (Iteration 1781 / 4900) loss: 1.465494
# (Iteration 1791 / 4900) loss: 1.312114
# (Iteration 1801 / 4900) loss: 1.657500
# (Iteration 1811 / 4900) loss: 1.533118
# (Iteration 1821 / 4900) loss: 1.303514
# (Iteration 1831 / 4900) loss: 1.374209
# (Iteration 1841 / 4900) loss: 1.570854
# (Iteration 1851 / 4900) loss: 1.250323
# (Iteration 1861 / 4900) loss: 1.203957
# (Iteration 1871 / 4900) loss: 1.326041
# (Iteration 1881 / 4900) loss: 1.286491
# (Iteration 1891 / 4900) loss: 1.373827
# (Iteration 1901 / 4900) loss: 1.280265
# (Iteration 1911 / 4900) loss: 1.469472
# (Iteration 1921 / 4900) loss: 1.413403
# (Iteration 1931 / 4900) loss: 1.372623
# (Iteration 1941 / 4900) loss: 1.363879
# (Iteration 1951 / 4900) loss: 1.458443
# (Epoch 4 / 10) train acc: 0.612000; val_acc: 0.564000
# (Iteration 1961 / 4900) loss: 1.325634
# (Iteration 1971 / 4900) loss: 1.263159
# (Iteration 1981 / 4900) loss: 1.631047
# (Iteration 1991 / 4900) loss: 1.542266
# (Iteration 2001 / 4900) loss: 1.366394
# (Iteration 2011 / 4900) loss: 1.672289
# (Iteration 2021 / 4900) loss: 1.381942
# (Iteration 2031 / 4900) loss: 1.298714
# (Iteration 2041 / 4900) loss: 1.376072
# (Iteration 2051 / 4900) loss: 1.270726
# (Iteration 2061 / 4900) loss: 1.527901
# (Iteration 2071 / 4900) loss: 1.390418
# (Iteration 2081 / 4900) loss: 1.564729
# (Iteration 2091 / 4900) loss: 1.544207
# (Iteration 2101 / 4900) loss: 1.515303
# (Iteration 2111 / 4900) loss: 1.552546
# (Iteration 2121 / 4900) loss: 1.450749
# (Iteration 2131 / 4900) loss: 1.273715
# (Iteration 2141 / 4900) loss: 1.484020
# (Iteration 2151 / 4900) loss: 1.302203
# (Iteration 2161 / 4900) loss: 1.146408
# (Iteration 2171 / 4900) loss: 1.431709
# (Iteration 2181 / 4900) loss: 1.464589
# (Iteration 2191 / 4900) loss: 1.299137
# (Iteration 2201 / 4900) loss: 1.199498
# (Iteration 2211 / 4900) loss: 1.390082
# (Iteration 2221 / 4900) loss: 1.206568
# (Iteration 2231 / 4900) loss: 1.226367
# (Iteration 2241 / 4900) loss: 1.530322
# (Iteration 2251 / 4900) loss: 1.508441
# (Iteration 2261 / 4900) loss: 1.448434
# (Iteration 2271 / 4900) loss: 1.225599
# (Iteration 2281 / 4900) loss: 1.502745
# (Iteration 2291 / 4900) loss: 1.270920
# (Iteration 2301 / 4900) loss: 1.312243
# (Iteration 2311 / 4900) loss: 1.389167
# (Iteration 2321 / 4900) loss: 1.325502
# (Iteration 2331 / 4900) loss: 1.287793
# (Iteration 2341 / 4900) loss: 1.432821
# (Iteration 2351 / 4900) loss: 1.606069
# (Iteration 2361 / 4900) loss: 1.409630
# (Iteration 2371 / 4900) loss: 1.350830
# (Iteration 2381 / 4900) loss: 1.348049
# (Iteration 2391 / 4900) loss: 1.505015
# (Iteration 2401 / 4900) loss: 1.338493
# (Iteration 2411 / 4900) loss: 1.364541
# (Iteration 2421 / 4900) loss: 1.279205
# (Iteration 2431 / 4900) loss: 1.669367
# (Iteration 2441 / 4900) loss: 1.455584
# (Epoch 5 / 10) train acc: 0.611000; val_acc: 0.540000
# (Iteration 2451 / 4900) loss: 1.410027
# (Iteration 2461 / 4900) loss: 1.320889
# (Iteration 2471 / 4900) loss: 1.495808
# (Iteration 2481 / 4900) loss: 1.375515
# (Iteration 2491 / 4900) loss: 1.366108
# (Iteration 2501 / 4900) loss: 1.118608
# (Iteration 2511 / 4900) loss: 1.347995
# (Iteration 2521 / 4900) loss: 1.390699
# (Iteration 2531 / 4900) loss: 1.343459
# (Iteration 2541 / 4900) loss: 1.414522
# (Iteration 2551 / 4900) loss: 1.371175
# (Iteration 2561 / 4900) loss: 1.334487
# (Iteration 2571 / 4900) loss: 1.444298
# (Iteration 2581 / 4900) loss: 1.372018
# (Iteration 2591 / 4900) loss: 1.212584
# (Iteration 2601 / 4900) loss: 1.306353
# (Iteration 2611 / 4900) loss: 1.484522
# (Iteration 2621 / 4900) loss: 1.292094
# (Iteration 2631 / 4900) loss: 1.570839
# (Iteration 2641 / 4900) loss: 1.520926
# (Iteration 2651 / 4900) loss: 1.432652
# (Iteration 2661 / 4900) loss: 1.282662
# (Iteration 2671 / 4900) loss: 1.340594
# (Iteration 2681 / 4900) loss: 1.435386
# (Iteration 2691 / 4900) loss: 1.235062
# (Iteration 2701 / 4900) loss: 1.381435
# (Iteration 2711 / 4900) loss: 1.208108
# (Iteration 2721 / 4900) loss: 1.366830
# (Iteration 2731 / 4900) loss: 1.579339
# (Iteration 2741 / 4900) loss: 1.561319
# (Iteration 2751 / 4900) loss: 1.298155
# (Iteration 2761 / 4900) loss: 1.391664
# (Iteration 2771 / 4900) loss: 1.394114
# (Iteration 2781 / 4900) loss: 1.285244
# (Iteration 2791 / 4900) loss: 1.373342
# (Iteration 2801 / 4900) loss: 1.342586
# (Iteration 2811 / 4900) loss: 1.131813
# (Iteration 2821 / 4900) loss: 1.258712
# (Iteration 2831 / 4900) loss: 1.243166
# (Iteration 2841 / 4900) loss: 1.437006
# (Iteration 2851 / 4900) loss: 1.539561
# (Iteration 2861 / 4900) loss: 1.382625
# (Iteration 2871 / 4900) loss: 1.405751
# (Iteration 2881 / 4900) loss: 1.363133
# (Iteration 2891 / 4900) loss: 1.375686
# (Iteration 2901 / 4900) loss: 1.441732
# (Iteration 2911 / 4900) loss: 1.325806
# (Iteration 2921 / 4900) loss: 1.452986
# (Iteration 2931 / 4900) loss: 1.362179
# (Epoch 6 / 10) train acc: 0.648000; val_acc: 0.539000
# (Iteration 2941 / 4900) loss: 1.355515
# (Iteration 2951 / 4900) loss: 1.632888
# (Iteration 2961 / 4900) loss: 1.737036
# (Iteration 2971 / 4900) loss: 1.270659
# (Iteration 2981 / 4900) loss: 1.367773
# (Iteration 2991 / 4900) loss: 1.362438
# (Iteration 3001 / 4900) loss: 1.162366
# (Iteration 3011 / 4900) loss: 1.374927
# (Iteration 3021 / 4900) loss: 1.355093
# (Iteration 3031 / 4900) loss: 1.451107
# (Iteration 3041 / 4900) loss: 1.381236
# (Iteration 3051 / 4900) loss: 1.507280
# (Iteration 3061 / 4900) loss: 1.450218
# (Iteration 3071 / 4900) loss: 1.299187
# (Iteration 3081 / 4900) loss: 1.616934
# (Iteration 3091 / 4900) loss: 1.774220
# (Iteration 3101 / 4900) loss: 1.433583
# (Iteration 3111 / 4900) loss: 1.459781
# (Iteration 3121 / 4900) loss: 1.438519
# (Iteration 3131 / 4900) loss: 1.337799
# (Iteration 3141 / 4900) loss: 1.201417
# (Iteration 3151 / 4900) loss: 1.354162
# (Iteration 3161 / 4900) loss: 1.358571
# (Iteration 3171 / 4900) loss: 1.344550
# (Iteration 3181 / 4900) loss: 1.380840
# (Iteration 3191 / 4900) loss: 1.362719
# (Iteration 3201 / 4900) loss: 1.303001
# (Iteration 3211 / 4900) loss: 1.364254
# (Iteration 3221 / 4900) loss: 1.386972
# (Iteration 3231 / 4900) loss: 1.241362
# (Iteration 3241 / 4900) loss: 1.313269
# (Iteration 3251 / 4900) loss: 1.459125
# (Iteration 3261 / 4900) loss: 1.184975
# (Iteration 3271 / 4900) loss: 1.299845
# (Iteration 3281 / 4900) loss: 1.502020
# (Iteration 3291 / 4900) loss: 1.416126
# (Iteration 3301 / 4900) loss: 1.338100
# (Iteration 3311 / 4900) loss: 1.497051
# (Iteration 3321 / 4900) loss: 1.504629
# (Iteration 3331 / 4900) loss: 1.362760
# (Iteration 3341 / 4900) loss: 1.529121
# (Iteration 3351 / 4900) loss: 1.344784
# (Iteration 3361 / 4900) loss: 1.245737
# (Iteration 3371 / 4900) loss: 1.521647
# (Iteration 3381 / 4900) loss: 1.529835
# (Iteration 3391 / 4900) loss: 1.605271
# (Iteration 3401 / 4900) loss: 1.382571
# (Iteration 3411 / 4900) loss: 1.317003
# (Iteration 3421 / 4900) loss: 1.274854
# (Epoch 7 / 10) train acc: 0.636000; val_acc: 0.545000
# (Iteration 3431 / 4900) loss: 1.345035
# (Iteration 3441 / 4900) loss: 1.522999
# (Iteration 3451 / 4900) loss: 1.328414
# (Iteration 3461 / 4900) loss: 1.231164
# (Iteration 3471 / 4900) loss: 1.314308
# (Iteration 3481 / 4900) loss: 1.246493
# (Iteration 3491 / 4900) loss: 1.363181
# (Iteration 3501 / 4900) loss: 1.539255
# (Iteration 3511 / 4900) loss: 1.231795
# (Iteration 3521 / 4900) loss: 1.275319
# (Iteration 3531 / 4900) loss: 1.382630
# (Iteration 3541 / 4900) loss: 1.270228
# (Iteration 3551 / 4900) loss: 1.475399
# (Iteration 3561 / 4900) loss: 1.401902
# (Iteration 3571 / 4900) loss: 1.403971
# (Iteration 3581 / 4900) loss: 1.600439
# (Iteration 3591 / 4900) loss: 1.394196
# (Iteration 3601 / 4900) loss: 1.386024
# (Iteration 3611 / 4900) loss: 1.413790
# (Iteration 3621 / 4900) loss: 1.376295
# (Iteration 3631 / 4900) loss: 1.497680
# (Iteration 3641 / 4900) loss: 1.247301
# (Iteration 3651 / 4900) loss: 1.451521
# (Iteration 3661 / 4900) loss: 1.320352
# (Iteration 3671 / 4900) loss: 1.207005
# (Iteration 3681 / 4900) loss: 1.345313
# (Iteration 3691 / 4900) loss: 1.243141
# (Iteration 3701 / 4900) loss: 1.540077
# (Iteration 3711 / 4900) loss: 1.309260
# (Iteration 3721 / 4900) loss: 1.337288
# (Iteration 3731 / 4900) loss: 1.417749
# (Iteration 3741 / 4900) loss: 1.342046
# (Iteration 3751 / 4900) loss: 1.428160
# (Iteration 3761 / 4900) loss: 1.258658
# (Iteration 3771 / 4900) loss: 1.507500
# (Iteration 3781 / 4900) loss: 1.260373
# (Iteration 3791 / 4900) loss: 1.391113
# (Iteration 3801 / 4900) loss: 1.342603
# (Iteration 3811 / 4900) loss: 1.305404
# (Iteration 3821 / 4900) loss: 1.330510
# (Iteration 3831 / 4900) loss: 1.357696
# (Iteration 3841 / 4900) loss: 1.233817
# (Iteration 3851 / 4900) loss: 1.229476
# (Iteration 3861 / 4900) loss: 1.659536
# (Iteration 3871 / 4900) loss: 1.489797
# (Iteration 3881 / 4900) loss: 1.314179
# (Iteration 3891 / 4900) loss: 1.413900
# (Iteration 3901 / 4900) loss: 1.494239
# (Iteration 3911 / 4900) loss: 1.568348
# (Epoch 8 / 10) train acc: 0.641000; val_acc: 0.537000
# (Iteration 3921 / 4900) loss: 1.192089
# (Iteration 3931 / 4900) loss: 1.355776
# (Iteration 3941 / 4900) loss: 1.421212
# (Iteration 3951 / 4900) loss: 1.521373
# (Iteration 3961 / 4900) loss: 1.258478
# (Iteration 3971 / 4900) loss: 1.322043
# (Iteration 3981 / 4900) loss: 1.183345
# (Iteration 3991 / 4900) loss: 1.496275
# (Iteration 4001 / 4900) loss: 1.286606
# (Iteration 4011 / 4900) loss: 1.484484
# (Iteration 4021 / 4900) loss: 1.485887
# (Iteration 4031 / 4900) loss: 1.285696
# (Iteration 4041 / 4900) loss: 1.436427
# (Iteration 4051 / 4900) loss: 1.605387
# (Iteration 4061 / 4900) loss: 1.220275
# (Iteration 4071 / 4900) loss: 1.276417
# (Iteration 4081 / 4900) loss: 1.513232
# (Iteration 4091 / 4900) loss: 1.374102
# (Iteration 4101 / 4900) loss: 1.437699
# (Iteration 4111 / 4900) loss: 1.198184
# (Iteration 4121 / 4900) loss: 1.204748
# (Iteration 4131 / 4900) loss: 1.451101
# (Iteration 4141 / 4900) loss: 1.375517
# (Iteration 4151 / 4900) loss: 1.476039
# (Iteration 4161 / 4900) loss: 1.271129
# (Iteration 4171 / 4900) loss: 1.416902
# (Iteration 4181 / 4900) loss: 1.519309
# (Iteration 4191 / 4900) loss: 1.405345
# (Iteration 4201 / 4900) loss: 1.582013
# (Iteration 4211 / 4900) loss: 1.302122
# (Iteration 4221 / 4900) loss: 1.302536
# (Iteration 4231 / 4900) loss: 1.456870
# (Iteration 4241 / 4900) loss: 1.307020
# (Iteration 4251 / 4900) loss: 1.376377
# (Iteration 4261 / 4900) loss: 1.307660
# (Iteration 4271 / 4900) loss: 1.270395
# (Iteration 4281 / 4900) loss: 1.365565
# (Iteration 4291 / 4900) loss: 1.441962
# (Iteration 4301 / 4900) loss: 1.318341
# (Iteration 4311 / 4900) loss: 1.293914
# (Iteration 4321 / 4900) loss: 1.356231
# (Iteration 4331 / 4900) loss: 1.453460
# (Iteration 4341 / 4900) loss: 1.382208
# (Iteration 4351 / 4900) loss: 1.354490
# (Iteration 4361 / 4900) loss: 1.208855
# (Iteration 4371 / 4900) loss: 1.279090
# (Iteration 4381 / 4900) loss: 1.414464
# (Iteration 4391 / 4900) loss: 1.449364
# (Iteration 4401 / 4900) loss: 1.326107
# (Epoch 9 / 10) train acc: 0.661000; val_acc: 0.528000
# (Iteration 4411 / 4900) loss: 1.361101
# (Iteration 4421 / 4900) loss: 1.371507
# (Iteration 4431 / 4900) loss: 1.494756
# (Iteration 4441 / 4900) loss: 1.641165
# (Iteration 4451 / 4900) loss: 1.559074
# (Iteration 4461 / 4900) loss: 1.161876
# (Iteration 4471 / 4900) loss: 1.242207
# (Iteration 4481 / 4900) loss: 1.304800
# (Iteration 4491 / 4900) loss: 1.359225
# (Iteration 4501 / 4900) loss: 1.544687
# (Iteration 4511 / 4900) loss: 1.274988
# (Iteration 4521 / 4900) loss: 1.461868
# (Iteration 4531 / 4900) loss: 1.301861
# (Iteration 4541 / 4900) loss: 1.180895
# (Iteration 4551 / 4900) loss: 1.376516
# (Iteration 4561 / 4900) loss: 1.258161
# (Iteration 4571 / 4900) loss: 1.282987
# (Iteration 4581 / 4900) loss: 1.162359
# (Iteration 4591 / 4900) loss: 1.558200
# (Iteration 4601 / 4900) loss: 1.290769
# (Iteration 4611 / 4900) loss: 1.365867
# (Iteration 4621 / 4900) loss: 1.415505
# (Iteration 4631 / 4900) loss: 1.666168
# (Iteration 4641 / 4900) loss: 1.581900
# (Iteration 4651 / 4900) loss: 1.430954
# (Iteration 4661 / 4900) loss: 1.258941
# (Iteration 4671 / 4900) loss: 1.390023
# (Iteration 4681 / 4900) loss: 1.262754
# (Iteration 4691 / 4900) loss: 1.284220
# (Iteration 4701 / 4900) loss: 1.332402
# (Iteration 4711 / 4900) loss: 1.357847
# (Iteration 4721 / 4900) loss: 1.234193
# (Iteration 4731 / 4900) loss: 1.334009
# (Iteration 4741 / 4900) loss: 1.360992
# (Iteration 4751 / 4900) loss: 1.237920
# (Iteration 4761 / 4900) loss: 1.224167
# (Iteration 4771 / 4900) loss: 1.349048
# (Iteration 4781 / 4900) loss: 1.374533
# (Iteration 4791 / 4900) loss: 1.386066
# (Iteration 4801 / 4900) loss: 1.159058
# (Iteration 4811 / 4900) loss: 1.288625
# (Iteration 4821 / 4900) loss: 1.563272
# (Iteration 4831 / 4900) loss: 1.309069
# (Iteration 4841 / 4900) loss: 1.438130
# (Iteration 4851 / 4900) loss: 1.295608
# (Iteration 4861 / 4900) loss: 1.259199
# (Iteration 4871 / 4900) loss: 1.164774
# (Iteration 4881 / 4900) loss: 1.392785
# (Iteration 4891 / 4900) loss: 1.349928
# (Epoch 10 / 10) train acc: 0.670000; val_acc: 0.538000
# train accuracy: 0.6700
# validation accuracy: 0.5380
# lr, rg:  1.0 0.003
# (Iteration 1 / 4900) loss: 2.302585
# (Epoch 0 / 10) train acc: 0.097000; val_acc: 0.113000
# (Iteration 11 / 4900) loss: 2.301807
# (Iteration 21 / 4900) loss: 2.299906
# (Iteration 31 / 4900) loss: 2.301174
# (Iteration 41 / 4900) loss: 2.060757
# (Iteration 51 / 4900) loss: 2.010785
# (Iteration 61 / 4900) loss: 1.848378
# (Iteration 71 / 4900) loss: 1.780695
# (Iteration 81 / 4900) loss: 1.764802
# (Iteration 91 / 4900) loss: 1.716231
# (Iteration 101 / 4900) loss: 1.646003
# (Iteration 111 / 4900) loss: 1.693170
# (Iteration 121 / 4900) loss: 1.452416
# (Iteration 131 / 4900) loss: 1.723353
# (Iteration 141 / 4900) loss: 1.410917
# (Iteration 151 / 4900) loss: 1.584566
# (Iteration 161 / 4900) loss: 1.658755
# (Iteration 171 / 4900) loss: 1.490579
# (Iteration 181 / 4900) loss: 1.498769
# (Iteration 191 / 4900) loss: 1.772827
# (Iteration 201 / 4900) loss: 1.569231
# (Iteration 211 / 4900) loss: 1.610585
# (Iteration 221 / 4900) loss: 1.405928
# (Iteration 231 / 4900) loss: 1.501100
# (Iteration 241 / 4900) loss: 1.524640
# (Iteration 251 / 4900) loss: 1.526727
# (Iteration 261 / 4900) loss: 1.865671
# (Iteration 271 / 4900) loss: 1.757332
# (Iteration 281 / 4900) loss: 1.696536
# (Iteration 291 / 4900) loss: 1.690020
# (Iteration 301 / 4900) loss: 1.750574
# (Iteration 311 / 4900) loss: 1.561624
# (Iteration 321 / 4900) loss: 1.480598
# (Iteration 331 / 4900) loss: 1.496138
# (Iteration 341 / 4900) loss: 1.679434
# (Iteration 351 / 4900) loss: 1.338358
# (Iteration 361 / 4900) loss: 1.844752
# (Iteration 371 / 4900) loss: 1.746564
# (Iteration 381 / 4900) loss: 1.561463
# (Iteration 391 / 4900) loss: 1.590198
# (Iteration 401 / 4900) loss: 1.735871
# (Iteration 411 / 4900) loss: 1.617365
# (Iteration 421 / 4900) loss: 1.718506
# (Iteration 431 / 4900) loss: 1.700551
# (Iteration 441 / 4900) loss: 1.531743
# (Iteration 451 / 4900) loss: 1.624222
# (Iteration 461 / 4900) loss: 1.459597
# (Iteration 471 / 4900) loss: 1.612460
# (Iteration 481 / 4900) loss: 1.651907
# (Epoch 1 / 10) train acc: 0.497000; val_acc: 0.485000
# (Iteration 491 / 4900) loss: 1.680655
# (Iteration 501 / 4900) loss: 1.452909
# (Iteration 511 / 4900) loss: 1.472882
# (Iteration 521 / 4900) loss: 1.506376
# (Iteration 531 / 4900) loss: 1.591470
# (Iteration 541 / 4900) loss: 1.542245
# (Iteration 551 / 4900) loss: 1.607182
# (Iteration 561 / 4900) loss: 1.704693
# (Iteration 571 / 4900) loss: 1.595075
# (Iteration 581 / 4900) loss: 1.339326
# (Iteration 591 / 4900) loss: 1.595589
# (Iteration 601 / 4900) loss: 1.653845
# (Iteration 611 / 4900) loss: 1.443077
# (Iteration 621 / 4900) loss: 1.513990
# (Iteration 631 / 4900) loss: 1.592288
# (Iteration 641 / 4900) loss: 1.514002
# (Iteration 651 / 4900) loss: 1.425707
# (Iteration 661 / 4900) loss: 1.653577
# (Iteration 671 / 4900) loss: 1.686614
# (Iteration 681 / 4900) loss: 1.514542
# (Iteration 691 / 4900) loss: 1.537560
# (Iteration 701 / 4900) loss: 1.545628
# (Iteration 711 / 4900) loss: 1.581726
# (Iteration 721 / 4900) loss: 1.483263
# (Iteration 731 / 4900) loss: 1.628194
# (Iteration 741 / 4900) loss: 1.510710
# (Iteration 751 / 4900) loss: 1.402606
# (Iteration 761 / 4900) loss: 1.605286
# (Iteration 771 / 4900) loss: 1.674387
# (Iteration 781 / 4900) loss: 1.633170
# (Iteration 791 / 4900) loss: 1.794477
# (Iteration 801 / 4900) loss: 1.612194
# (Iteration 811 / 4900) loss: 1.657049
# (Iteration 821 / 4900) loss: 1.451029
# (Iteration 831 / 4900) loss: 1.462491
# (Iteration 841 / 4900) loss: 1.595052
# (Iteration 851 / 4900) loss: 1.572902
# (Iteration 861 / 4900) loss: 1.481099
# (Iteration 871 / 4900) loss: 1.463170
# (Iteration 881 / 4900) loss: 1.469570
# (Iteration 891 / 4900) loss: 1.592235
# (Iteration 901 / 4900) loss: 1.642003
# (Iteration 911 / 4900) loss: 1.636111
# (Iteration 921 / 4900) loss: 1.683443
# (Iteration 931 / 4900) loss: 1.787371
# (Iteration 941 / 4900) loss: 1.617609
# (Iteration 951 / 4900) loss: 1.448900
# (Iteration 961 / 4900) loss: 1.431465
# (Iteration 971 / 4900) loss: 1.440148
# (Epoch 2 / 10) train acc: 0.548000; val_acc: 0.522000
# (Iteration 981 / 4900) loss: 1.437754
# (Iteration 991 / 4900) loss: 1.639983
# (Iteration 1001 / 4900) loss: 1.420036
# (Iteration 1011 / 4900) loss: 1.580638
# (Iteration 1021 / 4900) loss: 1.565651
# (Iteration 1031 / 4900) loss: 1.418545
# (Iteration 1041 / 4900) loss: 1.535349
# (Iteration 1051 / 4900) loss: 1.718303
# (Iteration 1061 / 4900) loss: 1.470218
# (Iteration 1071 / 4900) loss: 1.422955
# (Iteration 1081 / 4900) loss: 1.379572
# (Iteration 1091 / 4900) loss: 1.559651
# (Iteration 1101 / 4900) loss: 1.487096
# (Iteration 1111 / 4900) loss: 1.355340
# (Iteration 1121 / 4900) loss: 1.755054
# (Iteration 1131 / 4900) loss: 1.685573
# (Iteration 1141 / 4900) loss: 1.590061
# (Iteration 1151 / 4900) loss: 1.443704
# (Iteration 1161 / 4900) loss: 1.563791
# (Iteration 1171 / 4900) loss: 1.411471
# (Iteration 1181 / 4900) loss: 1.542391
# (Iteration 1191 / 4900) loss: 1.658673
# (Iteration 1201 / 4900) loss: 1.503552
# (Iteration 1211 / 4900) loss: 1.583085
# (Iteration 1221 / 4900) loss: 1.593633
# (Iteration 1231 / 4900) loss: 1.488292
# (Iteration 1241 / 4900) loss: 1.460970
# (Iteration 1251 / 4900) loss: 1.567851
# (Iteration 1261 / 4900) loss: 1.613018
# (Iteration 1271 / 4900) loss: 1.514236
# (Iteration 1281 / 4900) loss: 1.103786
# (Iteration 1291 / 4900) loss: 1.498281
# (Iteration 1301 / 4900) loss: 1.623287
# (Iteration 1311 / 4900) loss: 1.784097
# (Iteration 1321 / 4900) loss: 1.474002
# (Iteration 1331 / 4900) loss: 1.359574
# (Iteration 1341 / 4900) loss: 1.338101
# (Iteration 1351 / 4900) loss: 1.428594
# (Iteration 1361 / 4900) loss: 1.505386
# (Iteration 1371 / 4900) loss: 1.547984
# (Iteration 1381 / 4900) loss: 1.513202
# (Iteration 1391 / 4900) loss: 1.917850
# (Iteration 1401 / 4900) loss: 1.535226
# (Iteration 1411 / 4900) loss: 1.561510
# (Iteration 1421 / 4900) loss: 1.444419
# (Iteration 1431 / 4900) loss: 1.424251
# (Iteration 1441 / 4900) loss: 1.611981
# (Iteration 1451 / 4900) loss: 1.602552
# (Iteration 1461 / 4900) loss: 1.585953
# (Epoch 3 / 10) train acc: 0.572000; val_acc: 0.529000
# (Iteration 1471 / 4900) loss: 1.546031
# (Iteration 1481 / 4900) loss: 1.949555
# (Iteration 1491 / 4900) loss: 1.562585
# (Iteration 1501 / 4900) loss: 1.549393
# (Iteration 1511 / 4900) loss: 1.570346
# (Iteration 1521 / 4900) loss: 1.527483
# (Iteration 1531 / 4900) loss: 1.453893
# (Iteration 1541 / 4900) loss: 1.396913
# (Iteration 1551 / 4900) loss: 1.645356
# (Iteration 1561 / 4900) loss: 1.707928
# (Iteration 1571 / 4900) loss: 1.485484
# (Iteration 1581 / 4900) loss: 1.509920
# (Iteration 1591 / 4900) loss: 1.607530
# (Iteration 1601 / 4900) loss: 1.477033
# (Iteration 1611 / 4900) loss: 1.518021
# (Iteration 1621 / 4900) loss: 1.483857
# (Iteration 1631 / 4900) loss: 1.427665
# (Iteration 1641 / 4900) loss: 1.473366
# (Iteration 1651 / 4900) loss: 1.614492
# (Iteration 1661 / 4900) loss: 1.480289
# (Iteration 1671 / 4900) loss: 1.431911
# (Iteration 1681 / 4900) loss: 1.783805
# (Iteration 1691 / 4900) loss: 1.466138
# (Iteration 1701 / 4900) loss: 1.918870
# (Iteration 1711 / 4900) loss: 1.442552
# (Iteration 1721 / 4900) loss: 1.537033
# (Iteration 1731 / 4900) loss: 1.692190
# (Iteration 1741 / 4900) loss: 1.511235
# (Iteration 1751 / 4900) loss: 1.574384
# (Iteration 1761 / 4900) loss: 1.621169
# (Iteration 1771 / 4900) loss: 1.415541
# (Iteration 1781 / 4900) loss: 1.659282
# (Iteration 1791 / 4900) loss: 1.594571
# (Iteration 1801 / 4900) loss: 1.390288
# (Iteration 1811 / 4900) loss: 1.612284
# (Iteration 1821 / 4900) loss: 1.595822
# (Iteration 1831 / 4900) loss: 1.731404
# (Iteration 1841 / 4900) loss: 1.580463
# (Iteration 1851 / 4900) loss: 1.382101
# (Iteration 1861 / 4900) loss: 1.537049
# (Iteration 1871 / 4900) loss: 1.526789
# (Iteration 1881 / 4900) loss: 1.622403
# (Iteration 1891 / 4900) loss: 1.471535
# (Iteration 1901 / 4900) loss: 1.559462
# (Iteration 1911 / 4900) loss: 1.544119
# (Iteration 1921 / 4900) loss: 1.253047
# (Iteration 1931 / 4900) loss: 1.361078
# (Iteration 1941 / 4900) loss: 1.591956
# (Iteration 1951 / 4900) loss: 1.694242
# (Epoch 4 / 10) train acc: 0.571000; val_acc: 0.533000
# (Iteration 1961 / 4900) loss: 1.568529
# (Iteration 1971 / 4900) loss: 1.549695
# (Iteration 1981 / 4900) loss: 1.534172
# (Iteration 1991 / 4900) loss: 1.419460
# (Iteration 2001 / 4900) loss: 1.796689
# (Iteration 2011 / 4900) loss: 1.596618
# (Iteration 2021 / 4900) loss: 1.495809
# (Iteration 2031 / 4900) loss: 1.583966
# (Iteration 2041 / 4900) loss: 1.760622
# (Iteration 2051 / 4900) loss: 1.480319
# (Iteration 2061 / 4900) loss: 1.367996
# (Iteration 2071 / 4900) loss: 1.586349
# (Iteration 2081 / 4900) loss: 1.473268
# (Iteration 2091 / 4900) loss: 1.553287
# (Iteration 2101 / 4900) loss: 1.443610
# (Iteration 2111 / 4900) loss: 1.597256
# (Iteration 2121 / 4900) loss: 1.696697
# (Iteration 2131 / 4900) loss: 1.743636
# (Iteration 2141 / 4900) loss: 1.394475
# (Iteration 2151 / 4900) loss: 1.430784
# (Iteration 2161 / 4900) loss: 1.319117
# (Iteration 2171 / 4900) loss: 1.466530
# (Iteration 2181 / 4900) loss: 1.428328
# (Iteration 2191 / 4900) loss: 1.398329
# (Iteration 2201 / 4900) loss: 1.616654
# (Iteration 2211 / 4900) loss: 1.358928
# (Iteration 2221 / 4900) loss: 1.480918
# (Iteration 2231 / 4900) loss: 1.612561
# (Iteration 2241 / 4900) loss: 1.542220
# (Iteration 2251 / 4900) loss: 1.590169
# (Iteration 2261 / 4900) loss: 1.519217
# (Iteration 2271 / 4900) loss: 1.450757
# (Iteration 2281 / 4900) loss: 1.450628
# (Iteration 2291 / 4900) loss: 1.486570
# (Iteration 2301 / 4900) loss: 1.446578
# (Iteration 2311 / 4900) loss: 1.473187
# (Iteration 2321 / 4900) loss: 1.476558
# (Iteration 2331 / 4900) loss: 1.525938
# (Iteration 2341 / 4900) loss: 1.721368
# (Iteration 2351 / 4900) loss: 1.522913
# (Iteration 2361 / 4900) loss: 1.772570
# (Iteration 2371 / 4900) loss: 1.588725
# (Iteration 2381 / 4900) loss: 1.411197
# (Iteration 2391 / 4900) loss: 1.515447
# (Iteration 2401 / 4900) loss: 1.417816
# (Iteration 2411 / 4900) loss: 1.545618
# (Iteration 2421 / 4900) loss: 1.373087
# (Iteration 2431 / 4900) loss: 1.455926
# (Iteration 2441 / 4900) loss: 1.415606
# (Epoch 5 / 10) train acc: 0.582000; val_acc: 0.531000
# (Iteration 2451 / 4900) loss: 1.624986
# (Iteration 2461 / 4900) loss: 1.407013
# (Iteration 2471 / 4900) loss: 1.598047
# (Iteration 2481 / 4900) loss: 1.630188
# (Iteration 2491 / 4900) loss: 1.418394
# (Iteration 2501 / 4900) loss: 1.574533
# (Iteration 2511 / 4900) loss: 1.512617
# (Iteration 2521 / 4900) loss: 1.526857
# (Iteration 2531 / 4900) loss: 1.815881
# (Iteration 2541 / 4900) loss: 1.723643
# (Iteration 2551 / 4900) loss: 1.623144
# (Iteration 2561 / 4900) loss: 1.422626
# (Iteration 2571 / 4900) loss: 1.506350
# (Iteration 2581 / 4900) loss: 1.554940
# (Iteration 2591 / 4900) loss: 1.630619
# (Iteration 2601 / 4900) loss: 1.629838
# (Iteration 2611 / 4900) loss: 1.653717
# (Iteration 2621 / 4900) loss: 1.544290
# (Iteration 2631 / 4900) loss: 1.424544
# (Iteration 2641 / 4900) loss: 1.641180
# (Iteration 2651 / 4900) loss: 1.551144
# (Iteration 2661 / 4900) loss: 1.390229
# (Iteration 2671 / 4900) loss: 1.400253
# (Iteration 2681 / 4900) loss: 1.770754
# (Iteration 2691 / 4900) loss: 1.492043
# (Iteration 2701 / 4900) loss: 1.716813
# (Iteration 2711 / 4900) loss: 1.605136
# (Iteration 2721 / 4900) loss: 1.668416
# (Iteration 2731 / 4900) loss: 1.391696
# (Iteration 2741 / 4900) loss: 1.362593
# (Iteration 2751 / 4900) loss: 1.496687
# (Iteration 2761 / 4900) loss: 1.601388
# (Iteration 2771 / 4900) loss: 1.503513
# (Iteration 2781 / 4900) loss: 1.497739
# (Iteration 2791 / 4900) loss: 1.350073
# (Iteration 2801 / 4900) loss: 1.577901
# (Iteration 2811 / 4900) loss: 1.493926
# (Iteration 2821 / 4900) loss: 1.609451
# (Iteration 2831 / 4900) loss: 1.604244
# (Iteration 2841 / 4900) loss: 1.544919
# (Iteration 2851 / 4900) loss: 1.632175
# (Iteration 2861 / 4900) loss: 1.462144
# (Iteration 2871 / 4900) loss: 1.409593
# (Iteration 2881 / 4900) loss: 1.462880
# (Iteration 2891 / 4900) loss: 1.641083
# (Iteration 2901 / 4900) loss: 1.572223
# (Iteration 2911 / 4900) loss: 1.632629
# (Iteration 2921 / 4900) loss: 1.527394
# (Iteration 2931 / 4900) loss: 1.263179
# (Epoch 6 / 10) train acc: 0.589000; val_acc: 0.540000
# (Iteration 2941 / 4900) loss: 1.509428
# (Iteration 2951 / 4900) loss: 1.518531
# (Iteration 2961 / 4900) loss: 1.598715
# (Iteration 2971 / 4900) loss: 1.404726
# (Iteration 2981 / 4900) loss: 1.572266
# (Iteration 2991 / 4900) loss: 1.677281
# (Iteration 3001 / 4900) loss: 1.564405
# (Iteration 3011 / 4900) loss: 1.676155
# (Iteration 3021 / 4900) loss: 1.702747
# (Iteration 3031 / 4900) loss: 1.529839
# (Iteration 3041 / 4900) loss: 1.816372
# (Iteration 3051 / 4900) loss: 1.557293
# (Iteration 3061 / 4900) loss: 1.627858
# (Iteration 3071 / 4900) loss: 1.224219
# (Iteration 3081 / 4900) loss: 1.541255
# (Iteration 3091 / 4900) loss: 1.499185
# (Iteration 3101 / 4900) loss: 1.511108
# (Iteration 3111 / 4900) loss: 1.469688
# (Iteration 3121 / 4900) loss: 1.515737
# (Iteration 3131 / 4900) loss: 1.656782
# (Iteration 3141 / 4900) loss: 1.409916
# (Iteration 3151 / 4900) loss: 1.474978
# (Iteration 3161 / 4900) loss: 1.557099
# (Iteration 3171 / 4900) loss: 1.659976
# (Iteration 3181 / 4900) loss: 1.468384
# (Iteration 3191 / 4900) loss: 1.621152
# (Iteration 3201 / 4900) loss: 1.422470
# (Iteration 3211 / 4900) loss: 1.475691
# (Iteration 3221 / 4900) loss: 1.579671
# (Iteration 3231 / 4900) loss: 1.380216
# (Iteration 3241 / 4900) loss: 1.489502
# (Iteration 3251 / 4900) loss: 1.412732
# (Iteration 3261 / 4900) loss: 1.551194
# (Iteration 3271 / 4900) loss: 1.854707
# (Iteration 3281 / 4900) loss: 1.620152
# (Iteration 3291 / 4900) loss: 1.760490
# (Iteration 3301 / 4900) loss: 1.540398
# (Iteration 3311 / 4900) loss: 1.549923
# (Iteration 3321 / 4900) loss: 1.331873
# (Iteration 3331 / 4900) loss: 1.440386
# (Iteration 3341 / 4900) loss: 1.468659
# (Iteration 3351 / 4900) loss: 1.575435
# (Iteration 3361 / 4900) loss: 1.471620
# (Iteration 3371 / 4900) loss: 1.472338
# (Iteration 3381 / 4900) loss: 1.282820
# (Iteration 3391 / 4900) loss: 1.392727
# (Iteration 3401 / 4900) loss: 1.578944
# (Iteration 3411 / 4900) loss: 1.397917
# (Iteration 3421 / 4900) loss: 1.522679
# (Epoch 7 / 10) train acc: 0.607000; val_acc: 0.552000
# (Iteration 3431 / 4900) loss: 1.354354
# (Iteration 3441 / 4900) loss: 1.651366
# (Iteration 3451 / 4900) loss: 1.324269
# (Iteration 3461 / 4900) loss: 1.576118
# (Iteration 3471 / 4900) loss: 1.540424
# (Iteration 3481 / 4900) loss: 1.515745
# (Iteration 3491 / 4900) loss: 1.431358
# (Iteration 3501 / 4900) loss: 1.421697
# (Iteration 3511 / 4900) loss: 1.635480
# (Iteration 3521 / 4900) loss: 1.422590
# (Iteration 3531 / 4900) loss: 1.525563
# (Iteration 3541 / 4900) loss: 1.468374
# (Iteration 3551 / 4900) loss: 1.563330
# (Iteration 3561 / 4900) loss: 1.472076
# (Iteration 3571 / 4900) loss: 1.880370
# (Iteration 3581 / 4900) loss: 1.627794
# (Iteration 3591 / 4900) loss: 1.689707
# (Iteration 3601 / 4900) loss: 1.674038
# (Iteration 3611 / 4900) loss: 1.534050
# (Iteration 3621 / 4900) loss: 1.308446
# (Iteration 3631 / 4900) loss: 1.502206
# (Iteration 3641 / 4900) loss: 1.508789
# (Iteration 3651 / 4900) loss: 1.544192
# (Iteration 3661 / 4900) loss: 1.199042
# (Iteration 3671 / 4900) loss: 1.509454
# (Iteration 3681 / 4900) loss: 1.536899
# (Iteration 3691 / 4900) loss: 1.504187
# (Iteration 3701 / 4900) loss: 1.434099
# (Iteration 3711 / 4900) loss: 1.682769
# (Iteration 3721 / 4900) loss: 1.460251
# (Iteration 3731 / 4900) loss: 1.361376
# (Iteration 3741 / 4900) loss: 1.650337
# (Iteration 3751 / 4900) loss: 1.488674
# (Iteration 3761 / 4900) loss: 1.291010
# (Iteration 3771 / 4900) loss: 1.600368
# (Iteration 3781 / 4900) loss: 1.704185
# (Iteration 3791 / 4900) loss: 1.481808
# (Iteration 3801 / 4900) loss: 1.492703
# (Iteration 3811 / 4900) loss: 1.493279
# (Iteration 3821 / 4900) loss: 1.460403
# (Iteration 3831 / 4900) loss: 1.542867
# (Iteration 3841 / 4900) loss: 1.525160
# (Iteration 3851 / 4900) loss: 1.659954
# (Iteration 3861 / 4900) loss: 1.774557
# (Iteration 3871 / 4900) loss: 1.584322
# (Iteration 3881 / 4900) loss: 1.444052
# (Iteration 3891 / 4900) loss: 1.464077
# (Iteration 3901 / 4900) loss: 1.401603
# (Iteration 3911 / 4900) loss: 1.450753
# (Epoch 8 / 10) train acc: 0.581000; val_acc: 0.539000
# (Iteration 3921 / 4900) loss: 1.568781
# (Iteration 3931 / 4900) loss: 1.563814
# (Iteration 3941 / 4900) loss: 1.449063
# (Iteration 3951 / 4900) loss: 1.598875
# (Iteration 3961 / 4900) loss: 1.484074
# (Iteration 3971 / 4900) loss: 1.376679
# (Iteration 3981 / 4900) loss: 1.521034
# (Iteration 3991 / 4900) loss: 1.695228
# (Iteration 4001 / 4900) loss: 1.354788
# (Iteration 4011 / 4900) loss: 1.296518
# (Iteration 4021 / 4900) loss: 1.350837
# (Iteration 4031 / 4900) loss: 1.694371
# (Iteration 4041 / 4900) loss: 1.473051
# (Iteration 4051 / 4900) loss: 1.424859
# (Iteration 4061 / 4900) loss: 1.390743
# (Iteration 4071 / 4900) loss: 1.583883
# (Iteration 4081 / 4900) loss: 1.425167
# (Iteration 4091 / 4900) loss: 1.556129
# (Iteration 4101 / 4900) loss: 1.528226
# (Iteration 4111 / 4900) loss: 1.461418
# (Iteration 4121 / 4900) loss: 1.698134
# (Iteration 4131 / 4900) loss: 1.519300
# (Iteration 4141 / 4900) loss: 1.753232
# (Iteration 4151 / 4900) loss: 1.606686
# (Iteration 4161 / 4900) loss: 1.573313
# (Iteration 4171 / 4900) loss: 1.525275
# (Iteration 4181 / 4900) loss: 1.448869
# (Iteration 4191 / 4900) loss: 1.544598
# (Iteration 4201 / 4900) loss: 1.539323
# (Iteration 4211 / 4900) loss: 1.392910
# (Iteration 4221 / 4900) loss: 1.447934
# (Iteration 4231 / 4900) loss: 1.777475
# (Iteration 4241 / 4900) loss: 1.448046
# (Iteration 4251 / 4900) loss: 1.584522
# (Iteration 4261 / 4900) loss: 1.657098
# (Iteration 4271 / 4900) loss: 1.711452
# (Iteration 4281 / 4900) loss: 1.518850
# (Iteration 4291 / 4900) loss: 1.465833
# (Iteration 4301 / 4900) loss: 1.579065
# (Iteration 4311 / 4900) loss: 1.522534
# (Iteration 4321 / 4900) loss: 1.368742
# (Iteration 4331 / 4900) loss: 1.681339
# (Iteration 4341 / 4900) loss: 1.526176
# (Iteration 4351 / 4900) loss: 1.506301
# (Iteration 4361 / 4900) loss: 1.484693
# (Iteration 4371 / 4900) loss: 1.823845
# (Iteration 4381 / 4900) loss: 1.463055
# (Iteration 4391 / 4900) loss: 1.604305
# (Iteration 4401 / 4900) loss: 1.445048
# (Epoch 9 / 10) train acc: 0.559000; val_acc: 0.514000
# (Iteration 4411 / 4900) loss: 1.576047
# (Iteration 4421 / 4900) loss: 1.490070
# (Iteration 4431 / 4900) loss: 1.456500
# (Iteration 4441 / 4900) loss: 1.640250
# (Iteration 4451 / 4900) loss: 1.586634
# (Iteration 4461 / 4900) loss: 1.506338
# (Iteration 4471 / 4900) loss: 1.549130
# (Iteration 4481 / 4900) loss: 1.597504
# (Iteration 4491 / 4900) loss: 1.396558
# (Iteration 4501 / 4900) loss: 1.703264
# (Iteration 4511 / 4900) loss: 1.337000
# (Iteration 4521 / 4900) loss: 1.417961
# (Iteration 4531 / 4900) loss: 1.593432
# (Iteration 4541 / 4900) loss: 1.584473
# (Iteration 4551 / 4900) loss: 1.319218
# (Iteration 4561 / 4900) loss: 1.608113
# (Iteration 4571 / 4900) loss: 1.482004
# (Iteration 4581 / 4900) loss: 1.583088
# (Iteration 4591 / 4900) loss: 1.686747
# (Iteration 4601 / 4900) loss: 1.390724
# (Iteration 4611 / 4900) loss: 1.578232
# (Iteration 4621 / 4900) loss: 1.434628
# (Iteration 4631 / 4900) loss: 1.349130
# (Iteration 4641 / 4900) loss: 1.574994
# (Iteration 4651 / 4900) loss: 1.501480
# (Iteration 4661 / 4900) loss: 1.451379
# (Iteration 4671 / 4900) loss: 1.603183
# (Iteration 4681 / 4900) loss: 1.518034
# (Iteration 4691 / 4900) loss: 1.644294
# (Iteration 4701 / 4900) loss: 1.493922
# (Iteration 4711 / 4900) loss: 1.351955
# (Iteration 4721 / 4900) loss: 1.543548
# (Iteration 4731 / 4900) loss: 1.623421
# (Iteration 4741 / 4900) loss: 1.596872
# (Iteration 4751 / 4900) loss: 1.516616
# (Iteration 4761 / 4900) loss: 1.672939
# (Iteration 4771 / 4900) loss: 1.472578
# (Iteration 4781 / 4900) loss: 1.615664
# (Iteration 4791 / 4900) loss: 1.364127
# (Iteration 4801 / 4900) loss: 1.601750
# (Iteration 4811 / 4900) loss: 1.459775
# (Iteration 4821 / 4900) loss: 1.696003
# (Iteration 4831 / 4900) loss: 1.501812
# (Iteration 4841 / 4900) loss: 1.474242
# (Iteration 4851 / 4900) loss: 1.496058
# (Iteration 4861 / 4900) loss: 1.501362
# (Iteration 4871 / 4900) loss: 1.678664
# (Iteration 4881 / 4900) loss: 1.423404
# (Iteration 4891 / 4900) loss: 1.620266
# (Epoch 10 / 10) train acc: 0.605000; val_acc: 0.555000
# train accuracy: 0.6050
# validation accuracy: 0.5550

# %%
# Run your best neural net classifier on the test set. You should be able
# to get more than 55% accuracy.

y_test_pred = np.argmax(best_net.loss(data['X_test']), axis=1)
test_acc = (y_test_pred == data['y_test']).mean()
print(test_acc)
# Out:
# 0.541
